# %%
import yfinance as yf

ticker = yf.Ticker("VFINX")

# %%
ticker.info
# Out:
# {'previousClose': 298.16,
#  'regularMarketOpen': None,
#  'twoHundredDayAverage': 278.79495,
#  'trailingAnnualDividendYield': 0.017899785,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': None,
#  'navPrice': None,
#  'averageDailyVolume10Day': 0,
#  'totalAssets': 520283881472,
#  'regularMarketPreviousClose': 298.16,
#  'fiftyDayAverage': 292.44757,
#  'trailingAnnualDividendRate': 5.337,
#  'open': None,
#  'averageVolume10days': 0,
#  'expireDate': None,
#  'yield': 0.0177,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': None,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 13.731391,
#  'regularMarketVolume': None,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 0,
#  'priceToSalesTrailing12Months': None,
# ...

# %%
ticker.balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
ticker.history(period="max")
# Out:
#               Open    High     Low   Close  Volume  Dividends  Stock Splits
# Date
# 1980-01-02    4.84    4.84    4.84    4.84       0        0.0             0
# 1980-01-03    4.81    4.81    4.81    4.81       0        0.0             0
# 1980-01-04    4.87    4.87    4.87    4.87       0        0.0             0
# 1980-01-07    4.89    4.89    4.89    4.89       0        0.0             0
# 1980-01-08    4.98    4.98    4.98    4.98       0        0.0             0
# ...            ...     ...     ...     ...     ...        ...           ...
# 2019-12-26  298.95  298.95  298.95  298.95       0        0.0             0
# 2019-12-27  298.96  298.96  298.96  298.96       0        0.0             0
# 2019-12-30  297.27  297.27  297.27  297.27       0        0.0             0
# 2019-12-31  298.16  298.16  298.16  298.16       0        0.0             0
# 2020-01-02  300.69  300.69  300.69  300.69       0        0.0             0
#
# [10088 rows x 7 columns]

# %%
ticker.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1980-03-27      0.160           0.0
# 1980-06-27      0.160           0.0
# 1980-09-30      0.160           0.0
# 1980-12-30      0.350           0.0
# 1981-03-27      0.180           0.0
# ...               ...           ...
# 2018-09-25      1.150           0.0
# 2018-12-14      1.224           0.0
# 2019-03-20      1.390           0.0
# 2019-06-26      1.308           0.0
# 2019-09-25      1.229           0.0
#
# [160 rows x 2 columns]

# %%
df = ticker.history(period="max")

# %%
df.describe()
# Out:
#                Open          High           Low         Close   Volume  \
# count  10088.000000  10088.000000  10088.000000  10088.000000  10088.0
# mean      74.836947     74.836947     74.836947     74.836947      0.0
# std       68.041828     68.041828     68.041828     68.041828      0.0
# min        4.580000      4.580000      4.580000      4.580000      0.0
# 25%       16.907500     16.907500     16.907500     16.907500      0.0
# 50%       67.120000     67.120000     67.120000     67.120000      0.0
# 75%       99.125000     99.125000     99.125000     99.125000      0.0
# max      300.690000    300.690000    300.690000    300.690000      0.0
#
#           Dividends  Stock Splits
# count  10088.000000       10088.0
# mean       0.007685           0.0
# std        0.071907           0.0
# min        0.000000           0.0
# 25%        0.000000           0.0
# 50%        0.000000           0.0
# 75%        0.000000           0.0
# max        1.390000           0.0

# %%
df.tail(90)
# Out:
#               Open    High     Low   Close  Volume  Dividends  Stock Splits
# Date
# 2019-08-26  265.18  265.18  265.18  265.18       0        0.0             0
# 2019-08-27  264.32  264.32  264.32  264.32       0        0.0             0
# 2019-08-28  266.07  266.07  266.07  266.07       0        0.0             0
# 2019-08-29  269.48  269.48  269.48  269.48       0        0.0             0
# 2019-08-30  269.69  269.69  269.69  269.69       0        0.0             0
# ...            ...     ...     ...     ...     ...        ...           ...
# 2019-12-26  298.95  298.95  298.95  298.95       0        0.0             0
# 2019-12-27  298.96  298.96  298.96  298.96       0        0.0             0
# 2019-12-30  297.27  297.27  297.27  297.27       0        0.0             0
# 2019-12-31  298.16  298.16  298.16  298.16       0        0.0             0
# 2020-01-02  300.69  300.69  300.69  300.69       0        0.0             0
#
# [90 rows x 7 columns]

# %%
import yfinance as yf
data = yf.download(tickers="HDFCBANK.NS",
 period="5d",
 interval="1m")
data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Datetime
# 2020-01-03 15:25:00+05:30  1269.599976  1269.650024  1269.199951  1269.550049
# 2020-01-03 15:26:00+05:30  1269.500000  1269.949951  1269.349976  1269.650024
# 2020-01-03 15:27:00+05:30  1269.699951  1269.900024  1269.500000  1269.650024
# 2020-01-03 15:28:00+05:30  1269.849976  1270.000000  1268.800049  1268.900024
# 2020-01-03 15:29:00+05:30  1269.449951  1269.449951  1267.699951  1268.400024
#
#                              Adj Close  Volume
# Datetime
# 2020-01-03 15:25:00+05:30  1269.550049   54995
# 2020-01-03 15:26:00+05:30  1269.650024   60435
# 2020-01-03 15:27:00+05:30  1269.650024   45158
# 2020-01-03 15:28:00+05:30  1268.900024   55224
# 2020-01-03 15:29:00+05:30  1268.400024   18872

# %%
# Import the plotting library
# %matplotlib inline
import matplotlib.pyplot as plt
 
# Import the yfinance. If you get module not found error the run !pip install yfiannce from your Jupyter notebook
import yfinance as yf  
 
# Get the data of the stock AAPL
data = yf.download('vfinx BAH msft','2018-01-01','2019-12-01')
# Plot the close price of the AAPL
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  3 of 3 completed
