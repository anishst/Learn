# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [1,2,4,5]
y = [2,3,5,3]

plt.plot(x,y)
plt.title('First graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('x axis')
plt.ylabel('Y axis')
plt.show()

# %%
plt.plot(x,y)
plt.title('First graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('x axis')
plt.ylabel('Y axis')

# change tick values
plt.xticks([0,1,2,3])
plt.yticks([1,2,3])
plt.show()

# %%
df = pd.read_csv("vitals.csv", parse_dates=['Date'], index_col=['Date'])
df
# Out:
#             tony_height  tony_weight  leah_height  leah_weight
# Date
# 2018-10-29            3            7           11           22
# 2019-10-30            5           36           12           23
# 2020-10-31            7           56           22           66

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3 entries, 2018-10-29 to 2020-10-31
# Data columns (total 4 columns):
# tony_height    3 non-null int64
# tony_weight    3 non-null int64
# leah_height    3 non-null int64
# leah_weight    3 non-null int64
# dtypes: int64(4)
# memory usage: 120.0 bytes
# None

# %%
df.head()
# Out:
#             tony_height  tony_weight  leah_height  leah_weight
# Date
# 2018-10-29            3            7           11           22
# 2019-10-30            5           36           12           23
# 2020-10-31            7           56           22           66

# %%
# https://www.earthdatascience.org/courses/earth-analytics-python/use-time-series-data-in-python/customize-dates--matplotlib-plots-python/
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

fig, ax = plt.subplots(figsize=(15, 8))
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates

ax.plot(df.index.values,
        df['tony_height'].values,
        '-o',
        color='purple')
ax.set(xlabel="Date", ylabel="Tony Height",
       title="Health Info")

# Format the x axis
# Define the date format
# https://matplotlib.org/3.1.1/gallery/text_labels_and_annotations/date.html
date_form = DateFormatter("%m/%Y")
ax.xaxis.set_major_formatter(date_form)
