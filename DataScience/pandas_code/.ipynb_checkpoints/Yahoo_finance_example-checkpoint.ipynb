# %%
# http://www.augustkleimo.com/import-and-plot-stock-price-data-with-python-pandas-and-seaborn/
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn
# %matplotlib inline

# %%
open('DJI.csv','r').readlines()[:10]
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume\n',
#  '2018-10-29,24818.980469,25040.580078,24122.230469,24442.919922,24442.919922,443850000\n',
#  '2018-10-30,24482.039063,24906.679688,24415.689453,24874.640625,24874.640625,470050000\n',
#  '2018-10-31,25008.820313,25336.550781,25008.820313,25115.759766,25115.759766,448930000\n',
#  '2018-11-01,25142.080078,25396.470703,25108.109375,25380.740234,25380.740234,383970000\n',
#  '2018-11-02,25443.599609,25578.980469,25078.720703,25270.830078,25270.830078,429480000\n',
#  '2018-11-05,25261.470703,25507.349609,25261.470703,25461.699219,25461.699219,334740000\n',
#  '2018-11-06,25452.830078,25651.859375,25444.900391,25635.009766,25635.009766,265450000\n',
#  '2018-11-07,25788.460938,26200.140625,25765.880859,26180.300781,26180.300781,361780000\n',
#  '2018-11-08,26139.589844,26277.820313,26081.900391,26191.220703,26191.220703,295650000\n']

# %%
spy = pd.read_csv('DJI.csv',parse_dates=['Date'])

# %%
spy.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
spy.head()
# Out:
#         Date          Open          High           Low         Close  \
# 0 2018-10-29  24818.980469  25040.580078  24122.230469  24442.919922
# 1 2018-10-30  24482.039063  24906.679688  24415.689453  24874.640625
# 2 2018-10-31  25008.820313  25336.550781  25008.820313  25115.759766
# 3 2018-11-01  25142.080078  25396.470703  25108.109375  25380.740234
# 4 2018-11-02  25443.599609  25578.980469  25078.720703  25270.830078
#
#       Adj Close     Volume
# 0  24442.919922  443850000
# 1  24874.640625  470050000
# 2  25115.759766  448930000
# 3  25380.740234  383970000
# 4  25270.830078  429480000

# %%
# sort by date
spy = spy.sort_values(by='Date')
spy.set_index('Date',inplace=True)
spy['Close'].plot(figsize=(16, 12))
