# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

csv_file = 'vitals.csv'

df = pd.read_csv(csv_file)
df.Height.astype(int)
print(df)
# Out:
#          Date  Name  Height  Weight
# 0  2018-10-29  Tony       3       7
# 1  2018-10-30  Leah       5      36
# 2  2018-10-31  Tony       7      56

# %%
y = df['Height']
x = df['Date']

# %%
plt.scatter(x,y)
plt.plot(x,y, color='red')

# %%
tony = df.loc[df['Name'] == 'Tony']
print(tony)
# Out:
#          Date  Name  Height  Weight
# 0  2018-10-29  Tony       3       7
# 2  2018-10-31  Tony       7      56

# %%
tony_x = tony['Date']
tony_y = tony['Weight']

# %%
plt.plot(tony_x, tony_y)
